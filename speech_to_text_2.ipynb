# %% [markdown]
# # Speech-to-Text Model
#
# ### Objective:
#
# Use Convolutional Neural Networks to build a Speech-to-Text Model with Keras and Python. We will use the TensorFlow's Speech Commands Datasets which contains 65,000 one-second long utterances of 30 short words, by thousands of different people. This speech recognition system will understands simple spoken commands.
#
# ### Overview:
# 1. Data exploration and visualisation
# 2. Preprocessing the data
# 2. Building the model
# 3. Testing the model

# %% [markdown]
# ## Import libraries
# Start by importing the necessary libraries. LibROSA and SciPy are Python libraries used for processing audio signals.

# %%
import os
import librosa   #for audio processing
import IPython.display as ipd
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import wavfile #for audio processing
import warnings
warnings.filterwarnings("ignore")
import sounddevice as sd
import keras
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-fd607ad3798c> in <module>()
#       1 import os
# ----> 2 import librosa   #for audio processing
#       3 import IPython.display as ipd
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
#
# ImportError: No module named 'librosa'

# %% [markdown]
# ## Data Exploration and Visualisation

# %% [markdown]
# ### Visualisation of Audio signal in time series domain
# It's interesting to see what our audio data looks like. Let's represent the audio signal using its amplitude as a function of time. In other words, the features are the amplitudes which are recorded at different time intervals.

# %%
train_audio_path = 'speech_commands_v0.01/audio/'
samples, sample_rate = librosa.load(train_audio_path+'bed/0b77ee66_nohash_0.wav', sr = 16000)
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + '../input/train/audio/bed/0b77ee66_nohash_0.wav')
ax1.set_xlabel('Time')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, sample_rate/len(samples), sample_rate), samples)

# %% [markdown]
# ### Sampling rate
# We imported our audio data at a sampling rate of 16,000 Hz. This sampling rate produces a very high pitched sound:

# %%
ipd.Audio(samples, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print(sample_rate)
# Out:
# 16000

# %% [markdown]
# ### Resampling
# As most speech-related frequencies are present at 8000 Hz, let's resample to 8000 Hz. You will notice that the audio now sounds more natural and lifelike:

# %%
samples = librosa.resample(samples, sample_rate, 8000)
ipd.Audio(samples, rate=8000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Is our dataset balanced?
# Looking at the counts of recordings for each voice command, we see that the dataset is fairly balanced. It is okay that our dataset only contains a small number of background noise clips as we are not trying to identify the backround noise itself.

# %%
labels = [f for f in os.listdir(train_audio_path) if isdir(join(train_audio_path, f))]

#Measure count of each label
no_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    no_of_recordings.append(len(waves))
    
#plot bar chart
plt.figure(figsize=(30,5))
index = np.arange(len(labels))
plt.bar(index, no_of_recordings)
plt.xlabel('Commands', fontsize=12)
plt.ylabel('No of recordings', fontsize=12)
plt.xticks(index, labels, fontsize=15, rotation=60)
plt.title('No. of recordings for each command')
plt.show()

labels=["yes", "no", "up", "down", "left", "right", "on", "off", "stop", "go"]

# %% [markdown]
# ### Duration of recordings
# The description of the dataset mentions that the clips of voice commands last 1 second. We verify this by plotting a bar chart of for the duration of the audio clips and find that we've got some audio clips that are shorter than a second:

# %%
duration_of_recordings=[]
for label in labels:
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        sample_rate, samples = wavfile.read(train_audio_path + '/' + label + '/' + wav)
        duration_of_recordings.append(float(len(samples)/sample_rate))
    
plt.hist(np.array(duration_of_recordings))
# Out:
# (array([1.5000e+01, 3.0000e+01, 4.4000e+01, 1.3800e+02, 1.3600e+02,
#         1.7900e+02, 3.6600e+02, 4.3400e+02, 5.9300e+02, 2.1747e+04]),
#  array([0.418 , 0.4762, 0.5344, 0.5926, 0.6508, 0.709 , 0.7672, 0.8254,
#         0.8836, 0.9418, 1.    ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# Now that we've gotten to know our data a little better we can take the appropriate steps to clean and process it in preparation for feeding it to our model.
#
# First, we'll resample all of our audio clips from 16,000 Hz to 8000 Hz.
#
# Next, we'll remove any audio clips that are shorter than 1 second.
#
# Finally, we collect our audio clips in one list, and their corresponding labels in another list, allowing us to sort our data into predictor and target variables.
#
# We'll execute the above steps in one big loop.

# %%
from os.path import isdir, join

# %%
#View the speech command labels we are working with.
train_audio_path = 'speech_commands_v0.01/audio/'
labels = [f for f in os.listdir(train_audio_path) if isdir(join(train_audio_path, f))]
labels.sort()
print('Number of labels: ' + str(len(labels[1:])))
print(labels)
# Out:
# Number of labels: 30
# ['_background_noise_', 'bed', 'bird', 'cat', 'dog', 'down', 'eight', 'five', 'four', 'go', 'happy', 'house', 'left', 'marvin', 'nine', 'no', 'off', 'on', 'one', 'right', 'seven', 'sheila', 'six', 'stop', 'three', 'tree', 'two', 'up', 'wow', 'yes', 'zero']

# %%
background = [f for f in os.listdir(join(train_audio_path, '_background_noise_')) if f.endswith('.wav')]
background_noise = []
for wav in background : 
    samples, sample_rate = librosa.load(join(join(train_audio_path,'_background_noise_'),wav))
    samples = librosa.resample(samples, sample_rate, 8000)
    background_noise.append(samples)

# %%
all_wave = []
all_label = []
for label in labels[1:]:
    print(label)
    waves = [f for f in os.listdir(train_audio_path + '/'+ label) if f.endswith('.wav')]
    for wav in waves:
        samples, sample_rate = librosa.load(train_audio_path + '/' + label + '/' + wav, sr = 16000)
        samples = librosa.resample(samples, sample_rate, 8000)
        if(len(samples)== 8000) : 
            all_wave.append(samples)
            all_label.append(label)
# Out:
# bed
# bird
# cat
# dog
# down
# eight
# five
# four
# go
# happy
# house
# left
# marvin
# nine
# no
# off
# on
# one
# right
# seven
# sheila
# six
# stop
# three
# tree
# two
# up
# wow
# yes
# zero

# %% [markdown]
# ### Encoding the labels
# Our labels are categorical so we will first convert them into integer encoded data.
#
# After that, we convert the integer encoded labels into a one-hot vector as we are dealing with a multi-classification problem:

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y=le.fit_transform(all_label)
classes= list(le.classes_)

# %%
import keras
import keras.utils
from keras import utils as np_utils
#from keras.utils import np_utils
y=np_utils.to_categorical(y, num_classes=len(labels))

# %% [markdown]
# ### Reshaping the data
# We will need to reshape our data to fit into the layers the model will use.
#
# Currently our data is a 2-dimensional array. The Conv1D layer we will later use only accepts 3-dimensional input so we reshape our 2D array into a 3D array:

# %%
all_wave = np.array(all_wave).reshape(-1,8000,1)

# %% [markdown]
# ### Splitting the data
# We will train the model on 80% of the data and validate it on the remaining 20%:

# %%
from sklearn.model_selection import train_test_split
x_tr, x_val, y_tr, y_val = train_test_split(np.array(all_wave),np.array(y),stratify=y,test_size = 0.2,random_state=777,shuffle=True)

# %% [markdown]
# ## Building the model
#
# We will predominantly use 1D CNN in conjuction with 1D Max pooling.
#
# "A 1D CNN is very effective when you expect to derive interesting features from shorter (fixed-length) segments of the overall data set and where the location of the feature within the segment is not of high relevance."
#
# The pooling layer will help to avoid our model overfitting by reducing the dimension of the input data and thus varying the input data slightly.
#
#
# We will implement the model using Keras.

# %%
from keras.layers import Dense, Dropout, Flatten, Conv1D, Input, MaxPooling1D
from keras.models import Model
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K
K.clear_session()

inputs = Input(shape=(8000,1))

#First Conv1D layer
conv = Conv1D(8,13, padding='valid', activation='relu', strides=1)(inputs)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Second Conv1D layer
conv = Conv1D(16, 11, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Third Conv1D layer
conv = Conv1D(32, 9, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Fourth Conv1D layer
conv = Conv1D(64, 7, padding='valid', activation='relu', strides=1)(conv)
conv = MaxPooling1D(3)(conv)
conv = Dropout(0.3)(conv)

#Flatten layer
conv = Flatten()(conv)

#Dense Layer 1
conv = Dense(256, activation='relu')(conv)
conv = Dropout(0.3)(conv)

#Dense Layer 2
conv = Dense(128, activation='relu')(conv)
conv = Dropout(0.3)(conv)

outputs = Dense(len(labels), activation='softmax')(conv)

model = Model(inputs, outputs)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 8000, 1)           0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 7988, 8)           112
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 2662, 8)           0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 2662, 8)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 2652, 16)          1424
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 884, 16)           0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 884, 16)           0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 876, 32)           4640
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 292, 32)           0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 292, 32)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 286, 64)           14400
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 95, 64)            0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 95, 64)            0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6080)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               1556736
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 31)                3999
# =================================================================
# Total params: 1,614,207
# Trainable params: 1,614,207
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We will use categorical cross-entropy for our loss function we are dealing with a multi-classification problem:

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %% [markdown]
# To ensure that we don't continue training our model once the model performance has stopped improving on the validation set we will deploy early stopping in our callback.
#
# We also add a checkpoint to our callback to save the best model after every epoch:

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001) 
mc = ModelCheckpoint('best_model.hdf5', monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# %%
history=model.fit(x_tr, y_tr ,epochs=100, callbacks=[es,mc], batch_size=32, validation_data=(x_val,y_val))
# Out:
# Train on 46601 samples, validate on 11651 samples
# Epoch 1/100
# 46601/46601 [==============================] - 461s 10ms/step - loss: 2.8937 - accuracy: 0.1391 - val_loss: 2.2204 - val_accuracy: 0.3272
# Epoch 2/100
# 46601/46601 [==============================] - 440s 9ms/step - loss: 1.9947 - accuracy: 0.3772 - val_loss: 1.5728 - val_accuracy: 0.5454
# Epoch 3/100
# 46601/46601 [==============================] - 436s 9ms/step - loss: 1.5873 - accuracy: 0.5087 - val_loss: 1.4666 - val_accuracy: 0.5709
# Epoch 4/100
# 46601/46601 [==============================] - 413s 9ms/step - loss: 1.3763 - accuracy: 0.5741 - val_loss: 1.2866 - val_accuracy: 0.6051
# Epoch 5/100
# 46601/46601 [==============================] - 412s 9ms/step - loss: 1.2433 - accuracy: 0.6163 - val_loss: 1.0360 - val_accuracy: 0.6964
# Epoch 6/100
# 46601/46601 [==============================] - 409s 9ms/step - loss: 1.1518 - accuracy: 0.6489 - val_loss: 0.9196 - val_accuracy: 0.7319
# Epoch 7/100
# 46601/46601 [==============================] - 413s 9ms/step - loss: 1.0705 - accuracy: 0.6740 - val_loss: 0.8960 - val_accuracy: 0.7368
# Epoch 8/100
# 46601/46601 [==============================] - 419s 9ms/step - loss: 1.0259 - accuracy: 0.6867 - val_loss: 0.9545 - val_accuracy: 0.7141
# Epoch 9/100
# 46601/46601 [==============================] - 411s 9ms/step - loss: 0.9846 - accuracy: 0.7001 - val_loss: 0.8032 - val_accuracy: 0.7704
# Epoch 10/100
# 46601/46601 [==============================] - 483s 10ms/step - loss: 0.9388 - accuracy: 0.7153 - val_loss: 0.9069 - val_accuracy: 0.7302
# Epoch 11/100
# 46601/46601 [==============================] - 513s 11ms/step - loss: 0.9153 - accuracy: 0.7214 - val_loss: 0.8704 - val_accuracy: 0.7484
# Epoch 12/100
# 46601/46601 [==============================] - 492s 11ms/step - loss: 0.8808 - accuracy: 0.7301 - val_loss: 0.7512 - val_accuracy: 0.7845
# Epoch 13/100
# 46601/46601 [==============================] - 499s 11ms/step - loss: 0.8508 - accuracy: 0.7409 - val_loss: 0.7669 - val_accuracy: 0.7744
# Epoch 14/100
# 46601/46601 [==============================] - 492s 11ms/step - loss: 0.8260 - accuracy: 0.7468 - val_loss: 0.7133 - val_accuracy: 0.7917
# Epoch 15/100
# 46601/46601 [==============================] - 494s 11ms/step - loss: 0.8133 - accuracy: 0.7494 - val_loss: 0.7240 - val_accuracy: 0.7903
# Epoch 16/100
# 46601/46601 [==============================] - 492s 11ms/step - loss: 0.7898 - accuracy: 0.7589 - val_loss: 0.7991 - val_accuracy: 0.7630
# Epoch 17/100
# 46601/46601 [==============================] - 491s 11ms/step - loss: 0.7751 - accuracy: 0.7611 - val_loss: 0.6826 - val_accuracy: 0.8004
# Epoch 18/100
# 46601/46601 [==============================] - 502s 11ms/step - loss: 0.7565 - accuracy: 0.7681 - val_loss: 0.7399 - val_accuracy: 0.7829
# Epoch 19/100
# 46601/46601 [==============================] - 507s 11ms/step - loss: 0.7477 - accuracy: 0.7705 - val_loss: 0.7354 - val_accuracy: 0.7816
# Epoch 20/100
# 46601/46601 [==============================] - 490s 11ms/step - loss: 0.7301 - accuracy: 0.7729 - val_loss: 0.7337 - val_accuracy: 0.7915
# Epoch 21/100
# 46601/46601 [==============================] - 495s 11ms/step - loss: 0.7182 - accuracy: 0.7808 - val_loss: 0.6884 - val_accuracy: 0.8035
# Epoch 22/100
# 46601/46601 [==============================] - 492s 11ms/step - loss: 0.7173 - accuracy: 0.7822 - val_loss: 0.6615 - val_accuracy: 0.8086
# Epoch 23/100
# 46601/46601 [==============================] - 499s 11ms/step - loss: 0.6940 - accuracy: 0.7891 - val_loss: 0.6278 - val_accuracy: 0.8169
# Epoch 24/100
# 46601/46601 [==============================] - 507s 11ms/step - loss: 0.6994 - accuracy: 0.7867 - val_loss: 0.6497 - val_accuracy: 0.8087
# Epoch 25/100
# 46601/46601 [==============================] - 502s 11ms/step - loss: 0.6765 - accuracy: 0.7934 - val_loss: 0.6211 - val_accuracy: 0.8167
# Epoch 26/100
# 46601/46601 [==============================] - 489s 11ms/step - loss: 0.6765 - accuracy: 0.7926 - val_loss: 0.6366 - val_accuracy: 0.8165
# Epoch 27/100
# 46601/46601 [==============================] - 485s 10ms/step - loss: 0.6670 - accuracy: 0.7971 - val_loss: 0.6168 - val_accuracy: 0.8181
# Epoch 28/100
# 46601/46601 [==============================] - 497s 11ms/step - loss: 0.6580 - accuracy: 0.7959 - val_loss: 0.6407 - val_accuracy: 0.8159
# Epoch 29/100
# 46601/46601 [==============================] - 499s 11ms/step - loss: 0.6500 - accuracy: 0.8013 - val_loss: 0.7268 - val_accuracy: 0.7898
# Epoch 30/100
# 46601/46601 [==============================] - 500s 11ms/step - loss: 0.6493 - accuracy: 0.8014 - val_loss: 0.6264 - val_accuracy: 0.8174
# Epoch 31/100
# 46601/46601 [==============================] - 499s 11ms/step - loss: 0.6408 - accuracy: 0.8053 - val_loss: 0.6427 - val_accuracy: 0.8167
# Epoch 32/100
# 46601/46601 [==============================] - 508s 11ms/step - loss: 0.6378 - accuracy: 0.8049 - val_loss: 0.6278 - val_accuracy: 0.8188
# Epoch 33/100
# 46601/46601 [==============================] - 491s 11ms/step - loss: 0.6359 - accuracy: 0.8071 - val_loss: 0.6696 - val_accuracy: 0.8051
# Epoch 34/100
# 46601/46601 [==============================] - 492s 11ms/step - loss: 0.6294 - accuracy: 0.8089 - val_loss: 0.6597 - val_accuracy: 0.8110
# Epoch 35/100
# 46601/46601 [==============================] - 470s 10ms/step - loss: 0.6192 - accuracy: 0.8105 - val_loss: 0.6268 - val_accuracy: 0.8168
# Epoch 36/100
# 46601/46601 [==============================] - 476s 10ms/step - loss: 0.6166 - accuracy: 0.8102 - val_loss: 0.6293 - val_accuracy: 0.8171
# Epoch 37/100
# 46601/46601 [==============================] - 470s 10ms/step - loss: 0.6144 - accuracy: 0.8115 - val_loss: 0.5935 - val_accuracy: 0.8301
# Epoch 38/100
# 46601/46601 [==============================] - 465s 10ms/step - loss: 0.6073 - accuracy: 0.8129 - val_loss: 0.6349 - val_accuracy: 0.8192
# Epoch 39/100
# 46601/46601 [==============================] - 468s 10ms/step - loss: 0.6045 - accuracy: 0.8140 - val_loss: 0.6395 - val_accuracy: 0.8144
# Epoch 40/100
# 46601/46601 [==============================] - 470s 10ms/step - loss: 0.5998 - accuracy: 0.8179 - val_loss: 0.6284 - val_accuracy: 0.8213
# Epoch 41/100
# 46601/46601 [==============================] - 478s 10ms/step - loss: 0.5916 - accuracy: 0.8184 - val_loss: 0.6327 - val_accuracy: 0.8142
# Epoch 42/100
# 46601/46601 [==============================] - 473s 10ms/step - loss: 0.5895 - accuracy: 0.8223 - val_loss: 0.6254 - val_accuracy: 0.8206
# Epoch 43/100
# 46601/46601 [==============================] - 465s 10ms/step - loss: 0.5918 - accuracy: 0.8198 - val_loss: 0.6148 - val_accuracy: 0.8232
# Epoch 44/100
# 46601/46601 [==============================] - 474s 10ms/step - loss: 0.5817 - accuracy: 0.8219 - val_loss: 0.6083 - val_accuracy: 0.8272
# Epoch 45/100
# 46601/46601 [==============================] - 477s 10ms/step - loss: 0.5734 - accuracy: 0.8237 - val_loss: 0.5995 - val_accuracy: 0.8252
# Epoch 46/100
# 46601/46601 [==============================] - 480s 10ms/step - loss: 0.5678 - accuracy: 0.8253 - val_loss: 0.5959 - val_accuracy: 0.8279
# Epoch 47/100
# 46601/46601 [==============================] - 473s 10ms/step - loss: 0.5779 - accuracy: 0.8213 - val_loss: 0.6151 - val_accuracy: 0.8253
# Epoch 00047: early stopping

# %% [markdown]
# ## Evaluating the model
#
# Let's understand the performance of the model over time.
#
# We can see that the model reaches a validation accuracy of about 82.5% and a validation loss of 0.6151. The training and validation losses are in step with each other suggesting the model is not being underfit nor overfit.

# %%
from matplotlib import pyplot
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-82-a41ed7190e02> in <module>
#       1 from matplotlib import pyplot
# ----> 2 plt.plot(history.history['acc'])
#       3 plt.plot(history.history['val_acc'])
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'history' is not defined

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
pyplot.plot(history.history['acc'], label='train') 
pyplot.plot(history.history['val_acc'], label='test') 
pyplot.legend() 
pyplot.show()

# %%
print(history.history['loss'])
print(history.history['val_loss'])
print(history.history['acc'])
print(history.history['val_acc'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c9ef6cfdfed9> in <module>()
# ----> 1 print(history.history['loss'])
#       2 print(history.history['val_loss'])
#       3 print(history.history['acc'])
#       4 print(history.history['val_acc'])
#
# NameError: name 'history' is not defined

# %%
#save the model for later use.
model.save('first_speech_to_text_model.hdf5')

# %% [markdown]
# ## Testing the model

# %%
from keras.models import load_model
model=load_model('first_speech_to_text_model.hdf5')

# %%
#Defining a function that predicts text for the given audio
def predict(audio):
    prob=model.predict(audio.reshape(1,8000,1))
    index=np.argmax(prob[0])
    return classes[index]

# %%
#Selecting a random audio clip, feeding it into the model and viewing the outcome
import random
index=random.randint(0,len(x_val)-1)
samples=x_val[index].ravel()
print("Audio:",classes[np.argmax(y_val[index])])
ipd.Audio(samples, rate=8000)
print("Text:",predict(samples))
# Out:
# Audio: yes
# Text: yes

# %% [markdown]
# ## Record and test out your own audio clip on the model!
# The code below will allow you record an audio clip directly.

# %%
import sounddevice as sd
import soundfile as sf

samplerate = 16000  
duration = 1 # in seconds
filename = 'right.wav'
print("start")
mydata = sd.rec(int(samplerate * duration), samplerate=samplerate,
    channels=1, blocking=True)
print("end")
sd.wait()
sf.write(filename, mydata, samplerate)
# Out:
# start
# end

# %% [markdown]
# Now we read the above saved audio clip and let our model convert it into text:

# %%
#directory to your audio clips folder containing clips for testing
os.listdir('speech_commands_v0.01/test_audio/')
filepath='speech_commands_v0.01/test_audio/'

# %%
#reading the voice commands
samples_orig, sample_rate = librosa.load(filepath + '/' + 'right.wav', sr = 16000)
samples = librosa.resample(samples_orig[0:16000], sample_rate, 8000)
ipd.Audio(samples,rate=8000) 

#all_wave = np.array(all_wave).reshape(-1,8000,1)

predict(samples)
# Out:
# 'right'

# %%
#len(samples_orig)
# Out:
# 24768

# %%
#len(samples)
# Out:
# 8000
